# %%
import numpy as np
import tensorflow as tf
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
dataset_path = r'C:\Users\USER\Desktop\Brain tumor model\data image'

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.1
)

train_generator = train_datagen.flow_from_directory(
    dataset_path + "\\Training",
    target_size=(150,150),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    dataset_path + "\\Training",
    target_size=(150,150),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    dataset_path + "\\Testing",
    target_size=(150,150),
    batch_size=32,
    class_mode='categorical',
)
# Out:
# Found 5143 images belonging to 4 classes.
# Found 569 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
model = Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)),
    MaxPooling2D(2,2),

    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(512,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(512,activation='relu'),
    Dropout(0.5),
    Dense(4,activation='softmax')
])


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# c:\Users\USER\Desktop\Brain tumor model\brainenv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(train_generator, validation_data=val_generator, epochs=30)
# Out:
# Epoch 1/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 120s 732ms/step - accuracy: 0.5403 - loss: 1.0320 - val_accuracy: 0.5536 - val_loss: 1.0508
# Epoch 2/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 105s 651ms/step - accuracy: 0.6685 - loss: 0.8110 - val_accuracy: 0.5852 - val_loss: 0.9331
# Epoch 3/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 105s 648ms/step - accuracy: 0.7151 - loss: 0.7023 - val_accuracy: 0.6749 - val_loss: 0.7781
# Epoch 4/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 104s 643ms/step - accuracy: 0.7527 - loss: 0.6155 - val_accuracy: 0.7188 - val_loss: 0.7660
# Epoch 5/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 111s 688ms/step - accuracy: 0.7822 - loss: 0.5467 - val_accuracy: 0.6995 - val_loss: 0.7233
# Epoch 6/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 119s 740ms/step - accuracy: 0.7937 - loss: 0.5136 - val_accuracy: 0.7065 - val_loss: 0.7200
# Epoch 7/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 117s 724ms/step - accuracy: 0.8137 - loss: 0.4816 - val_accuracy: 0.8067 - val_loss: 0.5458
# Epoch 8/30
# ...

# %%
img_path = r'C:\Users\USER\Desktop\Brain tumor model\data image\pitutary_2.jpg'

# %%
class_labels = ["Glioma", "Meningioma", "No Tumor", "Pituitary"]

# %%
img = load_img(img_path, target_size=(150,150))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

prediction = model.predict(img_array)
predicted_index = np.argmax(prediction, axis=1)[0]
predicted_label = class_labels[predicted_index]
confidence = np.max(prediction) * 100

print(f'\npredicted class: {predicted_label}')
print(f'confidence: {confidence:.2f}%')


plt.imshow(img)
plt.title(f'prediction: {predicted_label} ({confidence:.2f}%)')
plt.axis('off')


plt.savefig("prediction_result.png")

print("Prediction image saved as prediction_result.png")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# predicted class: Pituitary
# confidence: 99.84%
# Prediction image saved as prediction_result.png

# %%
model.save("brain_tumor_model.h5")
print("Model saved successfully as brain_tumor_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully as brain_tumor_model.h5

# %% [markdown]
# Conclusion
#
# This project successfully developed a brain tumor detection system using Convolutional Neural Networks (CNN) and deep learning techniques to classify brain MRI images. The model was trained using preprocessed and augmented image data to improve accuracy and generalization. It can classify images into four categories: Glioma, Meningioma, Pituitary, and No Tumor. After training, the model achieved good accuracy and was able to predict tumor types from new MRI images with high confidence. The trained model was saved in .h5 format for future use and deployment. This project demonstrates the effectiveness of deep learning in medical image analysis and shows how AI can assist doctors in early detection and diagnosis of brain tumors, improving treatment planning and patient outcomes.
